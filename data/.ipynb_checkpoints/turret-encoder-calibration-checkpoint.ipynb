# %%
import pandas as pd

data = pd.read_excel("turret-calibration-use.xlsx", sheet_name="TurretEncoder calibration data")

# %%
data
# Out:
#       motorAngle  potentiometerVoltage  potentiometerAngle      Diff  \
# 0    -170.781342              0.234375         -169.552364 -1.228977
# 1    -170.781342              0.234375         -169.513195 -1.268147
# 2    -170.781342              0.234375         -169.513195 -1.268147
# 3    -170.781342              0.234375         -169.513195 -1.268147
# 4    -170.686127              0.234375         -169.367590 -1.318537
# ...          ...                   ...                 ...       ...
# 1973  170.035889              2.964844          170.871979 -0.836090
# 1974  170.035889              2.964844          170.891418 -0.855530
# 1975  170.035889              2.964844          170.818298 -0.782410
# 1976  170.035889              2.964844          170.863342 -0.827454
# 1977  170.035889              2.964844          170.841949 -0.806061
#
#       Pot Rotations
# 0          0.710227
# 1          0.710227
# 2          0.710227
# 3          0.710227
# 4          0.710227
# ...             ...
# 1973       8.984375
# 1974       8.984375
# 1975       8.984375
# 1976       8.984375
# 1977       8.984375
#
# [1978 rows x 5 columns]

# %%
potentiometerVoltage_data = data.drop(columns=["Diff", "Pot Rotations", "potentiometerAngle"])
potentiometerVoltage_data.columns
# Out:
# Index(['motorAngle', 'potentiometerVoltage', 'angle_bucket'], dtype='object')

# %%
potentiometerVoltage_data
# Out:
#       motorAngle  potentiometerVoltage  angle_bucket
# 0    -170.781342              0.234375        -171.0
# 1    -170.781342              0.234375        -171.0
# 2    -170.781342              0.234375        -171.0
# 3    -170.781342              0.234375        -171.0
# 4    -170.686127              0.234375        -170.5
# ...          ...                   ...           ...
# 1973  170.035889              2.964844         170.0
# 1974  170.035889              2.964844         170.0
# 1975  170.035889              2.964844         170.0
# 1976  170.035889              2.964844         170.0
# 1977  170.035889              2.964844         170.0
#
# [1978 rows x 3 columns]

# %% [markdown]
# ## Now bucket the data

# %%
potentiometerVoltage_data["angle_bucket"] = potentiometerVoltage_data.apply(lambda row: round(row["motorAngle"]*2)/2, axis=1)
potentiometerVoltage_data
# Out:
#       motorAngle  potentiometerVoltage  angle_bucket
# 0    -170.781342              0.234375        -171.0
# 1    -170.781342              0.234375        -171.0
# 2    -170.781342              0.234375        -171.0
# 3    -170.781342              0.234375        -171.0
# 4    -170.686127              0.234375        -170.5
# ...          ...                   ...           ...
# 1973  170.035889              2.964844         170.0
# 1974  170.035889              2.964844         170.0
# 1975  170.035889              2.964844         170.0
# 1976  170.035889              2.964844         170.0
# 1977  170.035889              2.964844         170.0
#
# [1978 rows x 3 columns]

# %% [markdown]
# ## Now get one from each group

# %%
one_data_point_per_group = potentiometerVoltage_data.groupby(["angle_bucket"]).first()

# %%
one_data_point_per_group
# Out:
#               motorAngle  potentiometerVoltage
# angle_bucket
# -171.0       -170.781342              0.234375
# -170.5       -170.686127              0.234375
# -170.0       -170.141968              0.238281
# -169.5       -169.611435              0.242188
# -169.0       -169.244125              0.242188
# ...                  ...                   ...
#  168.0        167.900116              2.949219
#  168.5        168.267426              2.949219
#  169.0        168.797958              2.957031
#  169.5        169.342117              2.957031
#  170.0        169.886261              2.964844
#
# [673 rows x 2 columns]

# %%
# Add in ideal voltage
one_data_point_per_group.columns
# Out:
# Index(['motorAngle', 'potentiometerVoltage'], dtype='object')

# %%
one_data_point_per_group
# Out:
#               motorAngle  potentiometerVoltage
# angle_bucket
# -171.0       -170.781342              0.234375
# -170.5       -170.686127              0.234375
# -170.0       -170.141968              0.238281
# -169.5       -169.611435              0.242188
# -169.0       -169.244125              0.242188
# ...                  ...                   ...
#  168.0        167.900116              2.949219
#  168.5        168.267426              2.949219
#  169.0        168.797958              2.957031
#  169.5        169.342117              2.957031
#  170.0        169.886261              2.964844
#
# [673 rows x 2 columns]

# %%
# https://stackoverflow.com/questions/32460593/including-the-group-name-in-the-apply-function-pandas-python
one_data_point_per_group["idealVoltage"] = one_data_point_per_group.apply(lambda row: (row["motorAngle"]+180)/360.0*3.3, axis=1)

# %%
one_data_point_per_group.drop(columns=["motorAngle"]).plot()
# Out:
# <AxesSubplot: xlabel='angle_bucket'>

# %% [markdown]
# # Prepare data for output

# %%
result_data = one_data_point_per_group.drop(columns=["idealVoltage"])
result_data["rotations"] = result_data.apply(lambda row: row["motorAngle"]/360.0, axis=1)
result_data.drop(columns=["motorAngle"], inplace=True)
result_data.rename(columns={"potentiometerVoltage": "voltage"}, inplace=True)
result_data
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[27], line 3
#       1 result_data = one_data_point_per_group.drop(columns=["idealVoltage"])
#       2 result_data["rotations"] = result_data.apply(lambda row: row["motorAngle"]/360.0, axis=1)
# ----> 3 result_data.drop(columns=["encoderAngle"], inplace=True)
#       4 result_data.rename(columns={"potentiometerVoltage": "voltage"}, inplace=True)
#       5 result_data
#
# File ~/Documents/Robotics/FRC/TurretSwerve/venv/lib/python3.9/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~/Documents/Robotics/FRC/TurretSwerve/venv/lib/python3.9/site-packages/pandas/core/frame.py:5396, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5248 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5249 def drop(  # type: ignore[override]
#    5250     self,
#    (...)
#    5257     errors: IgnoreRaise = "raise",
#    5258 ) -> DataFrame | None:
#    5259     """
#    5260     Drop specified labels from rows or columns.
#    5261
#    (...)
#    5394             weight  1.0     0.8
#    5395     """
# -> 5396     return super().drop(
#    5397         labels=labels,
#    5398         axis=axis,
#    5399         index=index,
#    5400         columns=columns,
#    5401         level=level,
#    5402         inplace=inplace,
#    5403         errors=errors,
#    5404     )
#
# File ~/Documents/Robotics/FRC/TurretSwerve/venv/lib/python3.9/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~/Documents/Robotics/FRC/TurretSwerve/venv/lib/python3.9/site-packages/pandas/core/generic.py:4505, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4503 for axis, labels in axes.items():
#    4504     if labels is not None:
# -> 4505         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4507 if inplace:
#    4508     self._update_inplace(obj)
#
# File ~/Documents/Robotics/FRC/TurretSwerve/venv/lib/python3.9/site-packages/pandas/core/generic.py:4546, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4544         new_axis = axis.drop(labels, level=level, errors=errors)
#    4545     else:
# -> 4546         new_axis = axis.drop(labels, errors=errors)
#    4547     indexer = axis.get_indexer(new_axis)
#    4549 # Case for non-unique axis
#    4550 else:
#
# File ~/Documents/Robotics/FRC/TurretSwerve/venv/lib/python3.9/site-packages/pandas/core/indexes/base.py:6977, in Index.drop(self, labels, errors)
#    6975 if mask.any():
#    6976     if errors != "ignore":
# -> 6977         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6978     indexer = indexer[~mask]
#    6979 return self.delete(indexer)
#
# KeyError: "['encoderAngle'] not found in axis"

# %%
result = result_data.to_json(orient="records", indent=4)
with open("cancoder-potentiometer-data-processed.json", "w") as f:
    f.write(result)

# %%
result
# Out:
# '[\n    {\n        "voltage":0.0,\n        "rotations":0.0012207031\n    },\n    {\n        "voltage":0.0078125,\n        "rotations":0.0161132812\n    },\n    {\n        "voltage":0.015625,\n        "rotations":0.0422363281\n    },\n    {\n        "voltage":0.0234375,\n        "rotations":0.0700683594\n    },\n    {\n        "voltage":0.03125,\n        "rotations":0.09765625\n    },\n    {\n        "voltage":0.04296875,\n        "rotations":0.1254882812\n    },\n    {\n        "voltage":0.046875,\n        "rotations":0.1528320312\n    },\n    {\n        "voltage":0.05859375,\n        "rotations":0.1809082031\n    },\n    {\n        "voltage":0.0703125,\n        "rotations":0.2099609375\n    },\n    {\n        "voltage":0.078125,\n        "rotations":0.2373046875\n    },\n    {\n        "voltage":0.08984375,\n        "rotations":0.2661132812\n    },\n    {\n        "voltage":0.09765625,\n        "rotations":0.2927246094\n    },\n    {\n        "voltage":0.109375,\n        "rotations":0.3200683594\n    },\n    {\n        "voltage":0.11328125,\n        "rotations":0.3479003906\n    },\n    {\n        "voltage":0.125,\n        "rotations":0.3759765625\n    },\n    {\n        "voltage":0.1328125,\n        "rotations":0.404296875\n    },\n    {\n        "voltage":0.1484375,\n        "rotations":0.4306640625\n    },\n    {\n        "voltage":0.15234375,\n        "rotations":0.4602050781\n    },\n    {\n        "voltage":0.1640625,\n        "rotations":0.486328125\n    },\n    {\n        "voltage":0.16796875,\n        "rotations":0.5153808594\n    },\n    {\n        "voltage":0.1875,\n        "rotations":0.5441894531\n    },\n    {\n        "voltage":0.19140625,\n        "rotations":0.5708007812\n    },\n    {\n        "voltage":0.20703125,\n        "rotations":0.5986328125\n    },\n    {\n        "voltage":0.21484375,\n        "rotations":0.6262207031\n    },\n    {\n        "voltage":0.22265625,\n        "rotations":0.6535644531\n    },\n    {\n        "voltage":0.234375,\n        "rotations":0.681640625\n    },\n    {\n        "voltage":0.23828125,\n        "rotations":0.7084960938\n    },\n    {\n        "voltage":0.25,\n        "rotations":0.7365722656\n    },\n    {\n        "voltage":0.26171875,\n        "rotations":0.7641601562\n    },\n    {\n        "voltage":0.26171875,\n        "rotations":0.7939453125\n    },\n    {\n        "voltage":0.26953125,\n        "rotations":0.8210449219\n    },\n    {\n        "voltage":0.28125,\n        "rotations":0.84765625\n    },\n    {\n        "voltage":0.28515625,\n        "rotations":0.875\n    },\n    {\n        "voltage":0.30859375,\n        "rotations":0.9033203125\n    },\n    {\n        "voltage":0.30859375,\n        "rotations":0.9321289062\n    },\n    {\n        "voltage":0.31640625,\n        "rotations":0.9594726562\n    },\n    {\n        "voltage":0.3359375,\n        "rotations":0.9870605469\n    },\n    {\n        "voltage":0.3359375,\n        "rotations":1.0141601562\n    },\n    {\n        "voltage":0.3359375,\n        "rotations":1.0427246094\n    },\n    {\n        "voltage":0.34765625,\n        "rotations":1.0705566406\n    },\n    {\n        "voltage":0.359375,\n        "rotations":1.0983886719\n    },\n    {\n        "voltage":0.37890625,\n        "rotations":1.126953125\n    },\n    {\n        "voltage":0.37890625,\n        "rotations":1.1538085938\n    },\n    {\n        "voltage":0.3984375,\n        "rotations":1.1823730469\n    },\n    {\n        "voltage":0.40625,\n        "rotations":1.208984375\n    },\n    {\n        "voltage":0.41796875,\n        "rotations":1.2377929688\n    },\n    {\n        "voltage":0.421875,\n        "rotations":1.2644042969\n    },\n    {\n        "voltage":0.43359375,\n        "rotations":1.2932128906\n    },\n    {\n        "voltage":0.43359375,\n        "rotations":1.3217773438\n    },\n    {\n        "voltage":0.44140625,\n        "rotations":1.3486328125\n    },\n    {\n        "voltage":0.4609375,\n        "rotations":1.37670898 ...
